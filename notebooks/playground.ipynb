# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config import DATA_DIR
from src.etl import load_protein_data, normalize_protein_data
from config import PROTEIN_METADATA, PROTEIN_SELECTED
import pandas as pd
import numpy as np

# %%
df = load_protein_data()[PROTEIN_METADATA + PROTEIN_SELECTED]

# %%
normalize_protein_data(df)
# Out:
#      patient_id        sample_id  tumor_type ajcc_stage  cancerseek_score  \
# 0       CRC 455    CRC 455 PLS 1  Colorectum          I          0.938342
# 1       CRC 456    CRC 456 PLS 1  Colorectum          I          0.925363
# 2       CRC 457    CRC 457 PLS 1  Colorectum         II          0.852367
# 3       CRC 458    CRC 458 PLS 1  Colorectum         II          0.617639
# 4       CRC 459    CRC 459 PLS 1  Colorectum         II          0.318434
# ...         ...              ...         ...        ...               ...
# 1812  PAPA 1353  PAPA 1353 PLS 1       Ovary          I          0.980312
# 1813  PAPA 1354  PAPA 1354 PLS 1       Ovary          I          0.999995
# 1814  PAPA 1355  PAPA 1355 PLS 1       Ovary        III          1.000000
# 1815  PAPA 1356  PAPA 1356 PLS 1       Ovary         II          1.000000
# 1816  PAPA 1357  PAPA 1357 PLS 1       Ovary        III          1.000000
#
#      cancerseek_result   ca_125      cea  ca19_9  prolactin      hgf  \
# ...
